# %% [markdown]
# ## Análises das flutuações do campo magnético observadas pela Cassini nas proximidades de Júpiter.

# %% [markdown]
# ### São 3 conjuntos de dados: um intervalo do background do vento solar; um intervalo com a ocorrência de ondas de foreshock; e um intervalo na magnetosheet de Júpiter.
# ### Analisando as séries individualmente. Iniciando pela série de magnetosheath.

# %%
# Iniciando com a série de magnetosheat. Foram criadas rotinas iniciais para abrir, converter os dados:
# %run ../rotinas/convert_extension_Dframe.py

# %% [markdown]
# ## 1. Magnetosheath

# %%
filename = 'msh5s.DAT'
df = convertDframe(filename)
df.head()
# Out:
# 0         A       Br       Bt       Bn     Bmag
# 1  28.50004 -0.25237  0.62433 -0.60463  0.90508
# 2  28.50010 -0.25746  0.62187 -0.60667  0.90637
# 3  28.50015 -0.26621  0.62008 -0.62538  0.92004
# 4  28.50021 -0.26787  0.64546 -0.64213  0.94892
# 5  28.50027 -0.26317  0.64429 -0.65642  0.95683

# %%
df.describe()
# Out:
# 0                 A            Br            Bt            Bn          Bmag
# count  12960.000000  12960.000000  12960.000000  12960.000000  12960.000000
# mean      28.875018     -0.363654      0.687963     -0.265023      0.975599
# std        0.216520      0.288553      0.316246      0.412501      0.279966
# min       28.500040     -1.330730     -1.506240     -1.662530      0.063140
# 25%       28.687527     -0.544015      0.514465     -0.516460      0.801275
# 50%       28.875020     -0.388040      0.697915     -0.289295      0.967720
# 75%       29.062505     -0.213750      0.889543     -0.066025      1.153462
# max       29.250000      1.907130      1.655420      1.801460      2.339440

# %%
# Load other libraries
import matplotlib.pyplot as plt

# %%
# magnetic components
mag = [df['Bmag'],df['Br'],df['Bt'],df['Bn']]

# Plot numerical data
a = 2 # number of rows
b = 2 # number of columns
c = 1 # initialize plot counter

fig = plt.figure(figsize = (15,5))

for i in mag:
    plt.subplot(a,b,c)
    plt.plot(df['A'], i, color = 'black')
    plt.title('Magnetosheath - ' + i.name)
    plt.xlabel('December 2000', fontsize = 12)
    plt.ylabel(i.name, fontsize = 12)
    plt.yticks(fontsize = 12)
    plt.tight_layout()
    c = c + 1

plt.show()

# %%
# Está sendo analisando um total de 12960 pontos. O desvio padrão das componentes de Br e Bmag são os que 
#se encontram mais próximo.

# %%
# calculando o intervalo de tempo em minutos
t = df['A']
t.values

# intensidade das componentes RTN
y_br = df["Br"]
y_bt = df["Bt"]
y_bn = df["Bn"]
y_bo = df["Bmag"]

# %%
# rotina para calcular o Lomb-Scargle periodograma
# %run ../rotinas/lomb_scargle_fast.py

# %%
# calculando os períodos para a componente Br
freq, power = lomb_scargle_fast(t, y_br, dy=1, f0=0, df=None, Nf=None,
                      center_data=True, fit_offset=True,
                      use_fft=True, freq_oversampling=5, nyquist_factor=2,
                      trig_sum_kwds=None)

# %%
plt.plot(1./freq, power)

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_932\2841847385.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(1./freq, power)

# %%
plt.plot(1./freq, power)
plt.xlim(0,0.5)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_932\70047896.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(1./freq, power)

# %%
# calculando os períodos para a componente Br
freq, power = lomb_scargle_fast(t, y_bt, dy=1, f0=0, df=None, Nf=None,
                      center_data=True, fit_offset=True,
                      use_fft=True, freq_oversampling=5, nyquist_factor=2,
                      trig_sum_kwds=None)

plt.plot(1./freq, power)
plt.xlim(0,0.5)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_932\351665961.py:7: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(1./freq, power)
# (0.0, 0.5)

# %%
# calculando os períodos para a componente Br
freq, power = lomb_scargle_fast(t, y_bn, dy=1, f0=0, df=None, Nf=None,
                      center_data=True, fit_offset=True,
                      use_fft=True, freq_oversampling=5, nyquist_factor=2,
                      trig_sum_kwds=None)

plt.plot(1./freq, power)
plt.xlim(0,0.5)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_932\3371626008.py:7: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(1./freq, power)
# (0.0, 0.5)

# %%
# calculando os períodos para a componente Br
freq, power = lomb_scargle_fast(t, y_bo, dy=1, f0=0, df=None, Nf=None,
                      center_data=True, fit_offset=True,
                      use_fft=True, freq_oversampling=5, nyquist_factor=2,
                      trig_sum_kwds=None)

plt.plot(1./freq, power)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_932\2610714661.py:7: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(1./freq, power)

# %%
plt.plot(1./freq, power)
plt.xlim(0,0.5)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_932\70047896.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(1./freq, power)

# %% [markdown]
# ## 2. Foreshock:

# %%
filename = 'foreshock5s.DAT'
df = convertDframe(filename)
df.head()
# Out:
# 0         A       Br       Bt       Bn     Bmag
# 1  27.25002 -0.08300  0.19700 -0.00500  0.21400
# 2  27.25008 -0.08142  0.19804 -0.00679  0.21475
# 3  27.25013 -0.07983  0.19908 -0.00858  0.21550
# 4  27.25019 -0.07825  0.20013 -0.01038  0.21625
# 5  27.25025 -0.07667  0.20117 -0.01217  0.21700

# %%
df.describe()
# Out:
# 0                 A            Br            Bt            Bn          Bmag
# count  12960.000000  12960.000000  12960.000000  12960.000000  12960.000000
# mean      27.625017      0.056771      0.212628     -0.039232      0.266682
# std        0.216531      0.106977      0.089366      0.100963      0.093190
# min       27.250020     -0.263190     -0.121480     -0.622980      0.014870
# 25%       27.437515     -0.006972      0.170400     -0.095000      0.209160
# 50%       27.625020      0.038790      0.207620     -0.054010      0.238305
# 75%       27.812515      0.107710      0.248730      0.011683      0.302673
# max       28.000020      1.004340      0.872780      0.408630      1.131650

# %%
# magnetic components
mag = [df['Bmag'],df['Br'],df['Bt'],df['Bn']]

# Plot numerical data
a = 2 # number of rows
b = 2 # number of columns
c = 1 # initialize plot counter

fig = plt.figure(figsize = (15,5))

for i in mag:
    plt.subplot(a,b,c)
    plt.plot(df['A'], i, color = 'black')
    plt.title('Foreshock - ' + i.name)
    plt.xlabel('December 2000', fontsize = 12)
    plt.ylabel(i.name, fontsize = 12)
    plt.yticks(fontsize = 12)
    plt.tight_layout()
    c = c + 1

plt.show()

# %% [markdown]
# ## 3. Background Solar Wind

# %%
filename = 'backsw5s.DAT'
df = convertDframe(filename)
df.head()
# Out:
# 0         A       Br       Bt       Bn     Bmag
# 1  18.37502 -0.12450 -0.40575  0.27800  0.50800
# 2  18.37508 -0.10575 -0.41175  0.28700  0.51275
# 3  18.37514 -0.10500 -0.41450  0.27750  0.51000
# 4  18.37519 -0.11250 -0.42425  0.26900  0.51475
# 5  18.37525 -0.11075 -0.41699  0.27526  0.51175

# %%
df.describe()
# Out:
# 0                 A            Br            Bt            Bn          Bmag
# count  12961.000000  12961.000000  12961.000000  12961.000000  12961.000000
# mean      18.750035     -0.068561     -0.432748      0.180437      0.495919
# std        0.216540      0.108075      0.035598      0.094026      0.021001
# min       18.375020     -0.330250     -0.522210     -0.114620      0.412000
# 25%       18.562530     -0.127530     -0.456670      0.134840      0.484440
# 50%       18.750030     -0.079540     -0.436510      0.189360      0.499640
# 75%       18.937540     -0.041390     -0.416170      0.249460      0.510000
# max       19.125050      0.408260     -0.273590      0.393770      0.563560

# %%
# magnetic components
mag = [df['Bmag'],df['Br'],df['Bt'],df['Bn']]

# Plot numerical data
a = 2 # number of rows
b = 2 # number of columns
c = 1 # initialize plot counter

fig = plt.figure(figsize = (15,5))

for i in mag:
    plt.subplot(a,b,c)
    plt.plot(df['A'], i, color = 'black')
    plt.title('Background SW - ' + i.name)
    plt.xlabel('December 2000', fontsize = 12)
    plt.ylabel(i.name, fontsize = 12)
    plt.yticks(fontsize = 12)
    plt.tight_layout()
    c = c + 1

plt.show()
